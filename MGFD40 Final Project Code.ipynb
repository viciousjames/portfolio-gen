# %%
# !pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yfinance in c:\users\wang1427\appdata\roaming\python\python39\site-packages (0.2.14)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\wang1427\appdata\roaming\python\python39\site-packages (from yfinance) (2.3.6)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\wang1427\appdata\roaming\python\python39\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: requests>=2.26 in c:\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: html5lib>=1.1 in c:\users\wang1427\appdata\roaming\python\python39\site-packages (from yfinance) (1.1)
# Requirement already satisfied: cryptography>=3.3.2 in c:\anaconda3\lib\site-packages (from yfinance) (38.0.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in c:\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\wang1427\appdata\roaming\python\python39\site-packages (from yfinance) (2023.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in c:\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in c:\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: pycparser in c:\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
# !pip install matplotlib.pyplot
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in c:\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in c:\anaconda3\lib\site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: scipy>=1.3 in c:\anaconda3\lib\site-packages (from statsmodels) (1.9.3)
# Requirement already satisfied: pandas>=0.25 in c:\anaconda3\lib\site-packages (from statsmodels) (1.4.4)
# Requirement already satisfied: patsy>=0.5.2 in c:\anaconda3\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\anaconda3\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wang1427\appdata\roaming\python\python39\site-packages (from pandas>=0.25->statsmodels) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
# !pip install wbdata
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wbdata
#   Downloading wbdata-0.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests>=2.0 in c:\anaconda3\lib\site-packages (from wbdata) (2.28.1)
# Requirement already satisfied: decorator>=4.0 in c:\anaconda3\lib\site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: tabulate>=0.8.5 in c:\anaconda3\lib\site-packages (from wbdata) (0.8.10)
# Requirement already satisfied: appdirs<2.0,>=1.4 in c:\anaconda3\lib\site-packages (from wbdata) (1.4.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\anaconda3\lib\site-packages (from requests>=2.0->wbdata) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests>=2.0->wbdata) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\lib\site-packages (from requests>=2.0->wbdata) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests>=2.0->wbdata) (2022.9.24)
# Installing collected packages: wbdata
# Successfully installed wbdata-0.3.0
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in c:\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf

# %%
#download the data from yfinance
SP_500 = yf.download(tickers='^GSPC', start="2016-01-01", end="2022-12-31", interval = '1d', rounding= True)
#Calculated the daily return
SP_500['daily_returns'] = SP_500['Adj Close'].ffill().pct_change()*100
SP_500
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close  Adj Close      Volume  \
# Date
# 2016-01-04  2038.20  2038.20  1989.68  2012.66    2012.66  4304880000
# 2016-01-05  2013.78  2021.94  2004.17  2016.71    2016.71  3706620000
# 2016-01-06  2011.71  2011.71  1979.05  1990.26    1990.26  4336660000
# 2016-01-07  1985.32  1985.32  1938.83  1943.09    1943.09  5076590000
# 2016-01-08  1945.97  1960.40  1918.46  1922.03    1922.03  4664940000
# ...             ...      ...      ...      ...        ...         ...
# 2022-12-23  3815.11  3845.80  3797.01  3844.82    3844.82  2819280000
# 2022-12-27  3843.34  3846.65  3813.22  3829.25    3829.25  3030300000
# 2022-12-28  3829.56  3848.32  3780.78  3783.22    3783.22  3083520000
# 2022-12-29  3805.45  3858.19  3805.45  3849.28    3849.28  3003680000
# 2022-12-30  3829.06  3839.85  3800.34  3839.50    3839.50  2979870000
#
#             daily_returns
# Date
# 2016-01-04            NaN
# 2016-01-05       0.201226
# 2016-01-06      -1.311542
# 2016-01-07      -2.370042
# 2016-01-08      -1.083841
# ...                   ...
# 2022-12-23       0.586806
# 2022-12-27      -0.404960
# 2022-12-28      -1.202063
# 2022-12-29       1.746132
# 2022-12-30      -0.254073
#
# [1762 rows x 7 columns]

# %%
#download the data from yfinance
Africa = yf.download(tickers='AFK', start="1980-01-01", end="2022-12-31", interval = '1d', rounding= True)
#Calculated the daily return
Africa['daily_returns'] = Africa['Adj Close'].ffill().pct_change()*100
Africa
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close  Volume  daily_returns
# Date
# 2008-07-14  41.32  41.40  41.32  41.40      27.19    4000            NaN
# 2008-07-15  42.15  43.00  41.80  42.11      27.66    1400       1.728577
# 2008-07-16  41.41  41.41  40.40  40.40      26.54    1500      -4.049168
# 2008-07-17  41.49  42.27  41.49  41.88      27.51    6900       3.654861
# 2008-07-18  41.50  41.50  40.00  41.00      26.93    8100      -2.108324
# ...           ...    ...    ...    ...        ...     ...            ...
# 2022-12-23  16.24  16.47  16.10  16.27      16.27   25800       1.181592
# 2022-12-27  16.41  16.69  16.33  16.39      16.39   14000       0.737554
# 2022-12-28  16.33  16.34  16.10  16.15      16.15    9300      -1.464308
# 2022-12-29  16.31  16.42  16.26  16.30      16.30   11900       0.928793
# 2022-12-30  16.14  16.27  15.96  16.06      16.06   13900      -1.472393
#
# [3644 rows x 7 columns]

# %%
#download the data from yfinance
Europe = yf.download(tickers='FEZ', start="1980-01-01", end="2022-12-31", interval = '1d', rounding= True)
#Calculated the daily return
Europe['daily_returns'] = Europe['Adj Close'].ffill().pct_change()*100
Europe
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close   Volume  daily_returns
# Date
# 2002-10-21  24.36  25.00  24.36  25.00      13.18    46100            NaN
# 2002-10-22  24.59  24.59  24.50  24.50      12.92     2100      -1.972686
# 2002-10-23  23.83  23.88  23.33  23.88      12.59    87200      -2.554180
# 2002-10-24  24.22  24.22  23.74  23.78      12.54    61900      -0.397141
# 2002-10-25  24.05  24.05  24.05  24.05      12.68      500       1.116427
# ...           ...    ...    ...    ...        ...      ...            ...
# 2022-12-23  38.59  38.88  38.48  38.86      38.73  2814100       0.103386
# 2022-12-27  38.98  39.11  38.89  38.95      38.82  1670900       0.232378
# 2022-12-28  39.01  39.12  38.48  38.48      38.36  1122800      -1.184956
# 2022-12-29  39.02  39.35  38.99  39.26      39.13  1581400       2.007299
# 2022-12-30  38.86  39.01  38.63  38.70      38.58  2164300      -1.405571
#
# [5085 rows x 7 columns]

# %%
#download the data from yfinance
Asia = yf.download(tickers='GMF', start="1980-01-01", end="2022-12-31", interval = '1d', rounding= True)
#Calculated the daily return
Asia['daily_returns'] = Asia['Adj Close'].ffill().pct_change()*100
Asia
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close  Volume  daily_returns
# Date
# 2007-03-23  61.74  61.89  61.73  61.89      43.01    5200            NaN
# 2007-03-26  61.91  62.31  61.91  62.31      43.30    1500       0.674262
# 2007-03-27  61.87  61.89  61.79  61.79      42.94    2500      -0.831409
# 2007-03-28  60.72  60.73  60.72  60.73      42.20     800      -1.723335
# 2007-03-29  61.70  61.70  61.11  61.55      42.77    3100       1.350711
# ...           ...    ...    ...    ...        ...     ...            ...
# 2022-12-23  94.88  94.93  94.40  94.62      94.62   12900      -0.473335
# 2022-12-27  95.87  97.13  95.57  96.67      96.67   55600       2.166561
# 2022-12-28  96.19  96.22  95.05  95.17      95.17   11000      -1.551671
# 2022-12-29  96.24  97.11  96.14  96.98      96.98   29300       1.901860
# 2022-12-30  96.11  96.60  95.55  96.02      96.02   42900      -0.989895
#
# [3973 rows x 7 columns]

# %%
#download the data from yfinance
Latam = yf.download(tickers='ILF', start="1980-01-01", end="2022-12-31", interval = '1d', rounding= True)
#Calculated the daily return
Latam['daily_returns'] = Latam['Adj Close'].ffill().pct_change()*100
Latam
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close   Volume  daily_returns
# Date
# 2001-10-26   8.32   8.32   8.32   8.32       4.57     5000            NaN
# 2001-10-29   8.30   8.30   8.30   8.30       4.56    11500      -0.218818
# 2001-10-30   8.30   8.30   8.30   8.30       4.56        0       0.000000
# 2001-10-31   8.10   8.10   8.10   8.10       4.45     5000      -2.412281
# 2001-11-01   8.22   8.22   8.22   8.22       4.51    10000       1.348315
# ...           ...    ...    ...    ...        ...      ...            ...
# 2022-12-23  23.30  23.59  23.28  23.55      23.55   670400       2.257924
# 2022-12-27  23.00  23.22  22.80  23.05      23.05   590700      -2.123142
# 2022-12-28  23.29  23.37  23.08  23.19      23.19   465400       0.607375
# 2022-12-29  23.47  23.50  23.05  23.09      23.09  2023200      -0.431220
# 2022-12-30  23.00  23.19  22.79  22.89      22.89   319900      -0.866176
#
# [5332 rows x 7 columns]

# %%
#read this file
ff_daily = pd.read_csv("F-F_Research_Data_Factors_daily.CSV")
# Parse the dates properly. We will tranform yyyymm into a "real" date format.
ff_daily['Date'] = pd.to_datetime(ff_daily['date'], format="%Y%m%d")  # this will give us dates such as "1998-01-01", "1998-02-28".
ff_daily[ff_daily['Date'] == '2016-01-01'].index
# Out:
# Int64Index([], dtype='int64')

# %%
#Here I sliced my data set
ff_daily = ff_daily.set_index('date')
ff_daily = ff_daily.iloc[23637: ,]
ff_daily
# Out:
#           Mkt-RF   SMB   HML     RF       Date
# date
# 20160104   -1.59 -0.87  0.52  0.000 2016-01-04
# 20160105    0.12 -0.19  0.01  0.000 2016-01-05
# 20160106   -1.35 -0.14  0.00  0.000 2016-01-06
# 20160107   -2.44 -0.29  0.08  0.000 2016-01-07
# 20160108   -1.11 -0.49 -0.03  0.000 2016-01-08
# ...          ...   ...   ...    ...        ...
# 20221223    0.51 -0.60  1.15  0.016 2022-12-23
# 20221227   -0.51 -0.73  1.43  0.016 2022-12-27
# 20221228   -1.23 -0.24 -0.29  0.016 2022-12-28
# 20221229    1.87  1.26 -1.07  0.016 2022-12-29
# 20221230   -0.22  0.10 -0.03  0.016 2022-12-30
#
# [1762 rows x 5 columns]

# %%
Market_Return = ff_daily['Mkt-RF'].to_numpy()
Market_Return
# Out:
# array([-1.59,  0.12, -1.35, ..., -1.23,  1.87, -0.22])

# %%
tickers = ["AFK", "FEZ", "GMF", "ILF"] 
portfolio = []

for t in tickers:
    portfolio_tmp = yf.download(t, start="2016-01-01", end="2022-12-31", interval = '1d',  progress=False)
# rename the columns "Adj Close" with the ticker name
    portfolio_tmp = portfolio_tmp[["Adj Close"]].rename(columns={"Adj Close":t}) 
# store the retrieved data in df1
    portfolio.append(portfolio_tmp)  
# concatenate all the retrieved data in one dataframe
portfolio = pd.concat(portfolio, axis=1)  
portfolio
# Out:
#                   AFK        FEZ        GMF        ILF
# Date
# 2016-01-04  13.839751  27.455429  61.419949  15.040195
# 2016-01-05  13.761295  27.211021  61.652668  15.127508
# 2016-01-06  13.635764  26.746641  60.756271  14.800075
# 2016-01-07  13.204252  26.371874  58.765266  14.210691
# 2016-01-08  13.141485  26.103025  58.351540  14.072442
# ...               ...        ...        ...        ...
# 2022-12-23  16.270000  38.734707  94.620003  23.549999
# 2022-12-27  16.389999  38.824417  96.669998  23.049999
# 2022-12-28  16.150000  38.355930  95.169998  23.190001
# 2022-12-29  16.299999  39.133415  96.980003  23.090000
# 2022-12-30  16.059999  38.575222  96.019997  22.889999
#
# [1762 rows x 4 columns]

# %%
tickers = ["AFK", "FEZ", "GMF", "ILF"]  
stockreturns_array2 = []
for i in tickers:
    stock_array = yf.download(i, start="2016-01-01", end="2022-12-31", interval = '1d',  progress=False)
    stock_array = stock_array[["Adj Close"]].rename(columns={"Adj Close":i}) 
    stockreturns_array2.append(stock_array)  
stockreturns_array2 = pd.concat(stockreturns_array2, axis=1)  
stockreturns_array2
stockreturns_array2 = stockreturns_array2.pct_change()
stockreturns_gross = 1+stockreturns_array2

#Equal weighting portfolio, 0.25 each
stockreturns_gross.iloc[0] = [0.25, 0.25, 0.25, 0.25]
stockreturns_gross.head()
equal_weighted_returns = stockreturns_gross.cumprod()  # cumulative returns
equal_weighted_returns['val'] = equal_weighted_returns.sum(axis=1)
df1 = equal_weighted_returns
df1
# Out:
#                  AFK       FEZ       GMF       ILF       val
# Date
# 2016-01-04  0.250000  0.250000  0.250000  0.250000  1.000000
# 2016-01-05  0.248583  0.247774  0.250947  0.251451  0.998756
# 2016-01-06  0.246315  0.243546  0.247299  0.246009  0.983168
# 2016-01-07  0.238520  0.240134  0.239195  0.236212  0.954060
# 2016-01-08  0.237387  0.237685  0.237511  0.233914  0.946496
# ...              ...       ...       ...       ...       ...
# 2022-12-23  0.293900  0.352705  0.385135  0.391451  1.423192
# 2022-12-27  0.296067  0.353522  0.393480  0.383140  1.426209
# 2022-12-28  0.291732  0.349256  0.387374  0.385467  1.413830
# 2022-12-29  0.294442  0.356336  0.394741  0.383805  1.429324
# 2022-12-30  0.290106  0.351253  0.390834  0.380480  1.412674
#
# [1762 rows x 5 columns]

# %%
df1['daily_returns_Asia'] = df1['GMF']*Asia['daily_returns']
df1['daily_returns_Africa'] = df1['AFK']*Africa['daily_returns']
df1['daily_returns_Europe'] = df1['FEZ']*Europe['daily_returns']
df1['daily_returns_Latam'] = df1['ILF']*Latam['daily_returns']
df1['daily_returns_Port'] = df1['daily_returns_Asia']+df1['daily_returns_Africa']+df1['daily_returns_Europe']+df1['daily_returns_Latam']
df1['SP_500_daily_returns'] = SP_500['daily_returns']
df1['Excess_Market_return'] = Market_Return
df1
# Out:
#                  AFK       FEZ       GMF       ILF       val  \
# Date
# 2016-01-04  0.250000  0.250000  0.250000  0.250000  1.000000
# 2016-01-05  0.248583  0.247774  0.250947  0.251451  0.998756
# 2016-01-06  0.246315  0.243546  0.247299  0.246009  0.983168
# 2016-01-07  0.238520  0.240134  0.239195  0.236212  0.954060
# 2016-01-08  0.237387  0.237685  0.237511  0.233914  0.946496
# ...              ...       ...       ...       ...       ...
# 2022-12-23  0.293900  0.352705  0.385135  0.391451  1.423192
# 2022-12-27  0.296067  0.353522  0.393480  0.383140  1.426209
# 2022-12-28  0.291732  0.349256  0.387374  0.385467  1.413830
# 2022-12-29  0.294442  0.356336  0.394741  0.383805  1.429324
# 2022-12-30  0.290106  0.351253  0.390834  0.380480  1.412674
#
#             daily_returns_Asia  daily_returns_Africa  daily_returns_Europe  \
# Date
# 2016-01-04           -0.796028             -0.214900             -0.525847
# 2016-01-05            0.093972             -0.143689             -0.225578
# 2016-01-06           -0.357009             -0.214810             -0.411728
# 2016-01-07           -0.783405             -0.769421             -0.341124
# 2016-01-08           -0.169737             -0.107903             -0.243364
# ...                        ...                   ...                   ...
# 2022-12-23           -0.182298              0.347270              0.036465
# 2022-12-27            0.852498              0.218366              0.082151
# 2022-12-28           -0.601077             -0.427186             -0.413853
# 2022-12-29            0.750743              0.273475              0.715273
# 2022-12-30           -0.386884             -0.427150             -0.493711
#
#             daily_returns_Latam  daily_returns_Port  SP_500_daily_returns  \
# Date
# 2016-01-04            -0.616083           -2.152857                   NaN
# 2016-01-05             0.150470           -0.124825              0.201226
# 2016-01-06            -0.536569           -1.520115             -1.311542
# 2016-01-07            -0.941656           -2.835606             -2.370042
# 2016-01-08            -0.230457           -0.751461             -1.083841
# ...                         ...                 ...                   ...
# 2022-12-23             0.883867            1.085303              0.586806
# 2022-12-27            -0.813461            0.339553             -0.404960
# 2022-12-28             0.234123           -1.207993             -1.202063
# 2022-12-29            -0.165504            1.573986              1.746132
# 2022-12-30            -0.329563           -1.637309             -0.254073
#
#             Excess_Market_return
# Date
# 2016-01-04                 -1.59
# 2016-01-05                  0.12
# 2016-01-06                 -1.35
# 2016-01-07                 -2.44
# 2016-01-08                 -1.11
# ...                          ...
# 2022-12-23                  0.51
# 2022-12-27                 -0.51
# 2022-12-28                 -1.23
# 2022-12-29                  1.87
# 2022-12-30                 -0.22
#
# [1762 rows x 12 columns]

# %%
fig = plt.figure()
ax1 = fig.add_axes([2.5,2,1,1])
ax1.plot(df1['daily_returns_Port'])
ax1.set_xlabel("Date")
ax1.set_ylabel("Percent")
ax1.set_title("World Portfolio daily returns")

plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,1,1])
ax1.plot(df1['SP_500_daily_returns'])
ax1.set_xlabel("Date")
ax1.set_ylabel("Percent")
ax1.set_title("SP 500 daily returns")

plt.show()

# %%
df1['Ret_lag'] = df1['daily_returns_Port'].shift()
# this is my regression model
reg = smf.ols("Excess_Market_return~Ret_lag", data=df1).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Excess_Market_return   R-squared:                       0.012
# Model:                              OLS   Adj. R-squared:                  0.011
# Method:                   Least Squares   F-statistic:                     21.19
# Date:                  Sat, 08 Apr 2023   Prob (F-statistic):           4.45e-06
# Time:                          15:28:51   Log-Likelihood:                -2874.7
# No. Observations:                  1761   AIC:                             5753.
# Df Residuals:                      1759   BIC:                             5764.
# Df Model:                             1
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0515      0.030      1.742      0.082      -0.006       0.109
# Ret_lag       -0.0795      0.017     -4.604      0.000      -0.113      -0.046
# ==============================================================================
# Omnibus:                      480.618   Durbin-Watson:                   2.131
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11388.095
# Skew:                          -0.715   Prob(JB):                         0.00
# Kurtosis:                      15.376   Cond. No.                         1.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df1['Ret_lag_AFK'] = df1['daily_returns_Africa'].shift()
# this is my regression model
reg = smf.ols("Excess_Market_return~Ret_lag_AFK", data=df1).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Excess_Market_return   R-squared:                       0.004
# Model:                              OLS   Adj. R-squared:                  0.003
# Method:                   Least Squares   F-statistic:                     6.708
# Date:                  Sat, 08 Apr 2023   Prob (F-statistic):            0.00968
# Time:                          15:28:51   Log-Likelihood:                -2881.9
# No. Observations:                  1761   AIC:                             5768.
# Df Residuals:                      1759   BIC:                             5779.
# Df Model:                             1
# Covariance Type:              nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0486      0.030      1.641      0.101      -0.010       0.107
# Ret_lag_AFK    -0.1908      0.074     -2.590      0.010      -0.335      -0.046
# ==============================================================================
# Omnibus:                      485.353   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13125.257
# Skew:                          -0.685   Prob(JB):                         0.00
# Kurtosis:                      16.304   Cond. No.                         2.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df1['Ret_lag_ILF'] = df1['daily_returns_Latam'].shift()
# this is my regression model
reg = smf.ols("Excess_Market_return~Ret_lag_ILF", data=df1).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Excess_Market_return   R-squared:                       0.011
# Model:                              OLS   Adj. R-squared:                  0.011
# Method:                   Least Squares   F-statistic:                     20.18
# Date:                  Sat, 08 Apr 2023   Prob (F-statistic):           7.49e-06
# Time:                          15:28:51   Log-Likelihood:                -2875.2
# No. Observations:                  1761   AIC:                             5754.
# Df Residuals:                      1759   BIC:                             5765.
# Df Model:                             1
# Covariance Type:              nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0512      0.030      1.732      0.083      -0.007       0.109
# Ret_lag_ILF    -0.1923      0.043     -4.493      0.000      -0.276      -0.108
# ==============================================================================
# Omnibus:                      469.328   Durbin-Watson:                   2.180
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11040.062
# Skew:                          -0.685   Prob(JB):                         0.00
# Kurtosis:                      15.189   Cond. No.                         1.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df1['Ret_lag_FEZ'] = df1['daily_returns_Europe'].shift()
# this is my regression model
reg = smf.ols("Excess_Market_return~Ret_lag_FEZ", data=df1).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Excess_Market_return   R-squared:                       0.007
# Model:                              OLS   Adj. R-squared:                  0.006
# Method:                   Least Squares   F-statistic:                     12.00
# Date:                  Sat, 08 Apr 2023   Prob (F-statistic):           0.000545
# Time:                          15:28:51   Log-Likelihood:                -2879.3
# No. Observations:                  1761   AIC:                             5763.
# Df Residuals:                      1759   BIC:                             5774.
# Df Model:                             1
# Covariance Type:              nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0500      0.030      1.688      0.092      -0.008       0.108
# Ret_lag_FEZ    -0.2445      0.071     -3.464      0.001      -0.383      -0.106
# ==============================================================================
# Omnibus:                      476.074   Durbin-Watson:                   2.171
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11995.227
# Skew:                          -0.682   Prob(JB):                         0.00
# Kurtosis:                      15.713   Cond. No.                         2.39
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df1['Ret_lag_GMF'] = df1['daily_returns_Asia'].shift()
# this is my regression model
reg = smf.ols("Excess_Market_return~Ret_lag_GMF", data=df1).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Excess_Market_return   R-squared:                       0.012
# Model:                              OLS   Adj. R-squared:                  0.012
# Method:                   Least Squares   F-statistic:                     21.93
# Date:                  Sat, 08 Apr 2023   Prob (F-statistic):           3.05e-06
# Time:                          15:28:51   Log-Likelihood:                -2874.4
# No. Observations:                  1761   AIC:                             5753.
# Df Residuals:                      1759   BIC:                             5764.
# Df Model:                             1
# Covariance Type:              nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0511      0.030      1.730      0.084      -0.007       0.109
# Ret_lag_GMF    -0.2858      0.061     -4.683      0.000      -0.405      -0.166
# ==============================================================================
# Omnibus:                      469.351   Durbin-Watson:                   2.147
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10976.832
# Skew:                          -0.687   Prob(JB):                         0.00
# Kurtosis:                      15.154   Cond. No.                         2.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import wbdata

# Define the countries and indicators you want to retrieve
countries = ['HK', 'IN', 'TW', 'CN', 'TH', 'ID', 'MY', 'PH', 'SG', 'FR', 'DE',
             'NL', 'ES', 'IT', 'IE', 'BE', 'SE', 'FI', 'ZA', 'NG', 'KE',
             'MA', 'GB', 'EG', 'TZ', 'GH', 'AE', 'ZM', 'ZW', 'BR', 'MX',
             'CL', 'PE', 'CO']

indicators = {'NY.GDP.MKTP.CD': 'GDP (current US$)'}

# Retrieve data from the World Bank API
df = wbdata.get_dataframe(indicators, country=countries, convert_date=False)

# Rename the columns to make them more readable
df.columns = ['GDP']

df = df.reset_index()


gmf = pd.read_excel('world portfolio.xlsx', sheet_name="GMF")

GMF = pd.merge(df,gmf, on="country")
GMF['factor'] = GMF['GDP']*GMF['Weight']

sum_by_date = GMF.groupby('date')['factor'].sum()

for date in GMF['date'].unique():
    factor_sum = GMF.loc[GMF['date'] == date, 'factor'].sum()

gmf_factor_totals = {}
for date in GMF['date'].unique():
    gmf_factor_sum = GMF.loc[GMF['date'] == date, 'factor'].sum()
    gmf_factor_totals[date] = gmf_factor_sum

gm = pd.DataFrame({'Year': list(gmf_factor_totals.keys()), 'GDPwg': list(gmf_factor_totals.values())})

fez = pd.read_excel('world portfolio.xlsx', sheet_name="FEZ")

FEZ = pd.merge(df,fez, on="country")
FEZ['factor'] = FEZ['GDP']*FEZ['Weight']

sum_by_date = FEZ.groupby('date')['factor'].sum()

fez_factor_totals = {}
for date in FEZ['date'].unique():
    fez_factor_sum = FEZ.loc[FEZ['date'] == date, 'factor'].sum()
    fez_factor_totals[date] = fez_factor_sum

fe = pd.DataFrame({'Year': list(fez_factor_totals.keys()), 'GDPwf': list(fez_factor_totals.values())})


afk = pd.read_excel('world portfolio.xlsx', sheet_name="AFK")


AFK = pd.merge(df,afk, on="country")
AFK['factor'] = AFK['GDP']*AFK['Weight']


sum_by_date = AFK.groupby('date')['factor'].sum()



afk_factor_totals = {}
for date in AFK['date'].unique():
    afk_factor_sum = AFK.loc[AFK['date'] == date, 'factor'].sum()
    afk_factor_totals[date] = afk_factor_sum


af = pd.DataFrame({'Year': list(afk_factor_totals.keys()), 'GDPwa': list(afk_factor_totals.values())})


ilf = pd.read_excel('world portfolio.xlsx', sheet_name="ILF")


ILF = pd.merge(df,ilf, on="country")
ILF['factor'] = ILF['GDP']*ILF['Weight']


sum_by_date = ILF.groupby('date')['factor'].sum()



ilf_factor_totals = {}
for date in AFK['date'].unique():
    ilf_factor_sum = ILF.loc[ILF['date'] == date, 'factor'].sum()
    ilf_factor_totals[date] = ilf_factor_sum


il = pd.DataFrame({'Year': list(ilf_factor_totals.keys()), 'GDPwi': list(ilf_factor_totals.values())})


merged_df = pd.merge(gm, fe, on='Year', how='outer')
merged_df = pd.merge(merged_df, af, on='Year', how='outer')
merged_df = pd.merge(merged_df, il, on='Year', how='outer')

# Fill any missing values with 0
merged_df = merged_df.fillna(0)

merged_df['Total'] = merged_df['GDPwg']+merged_df['GDPwf']+merged_df['GDPwa']+merged_df['GDPwi']

merged_df['gmf_weight'] = merged_df['GDPwg']/merged_df['Total']
merged_df['fez_weight'] = merged_df['GDPwf']/merged_df['Total']
merged_df['afk_weight'] = merged_df['GDPwa']/merged_df['Total']
merged_df['ilf_weight'] = merged_df['GDPwi']/merged_df['Total']

df_flipped = merged_df.iloc[:6][::-1][:len(df)]
print(df_flipped)
# Out:
#    Year         GDPwg         GDPwf         GDPwa         GDPwi         Total  \
# 5  2016  1.789134e+12  2.271046e+12  3.621915e+11  1.329505e+12  5.751876e+12
# 4  2017  1.991280e+12  2.399148e+12  3.781434e+11  1.503792e+12  6.272363e+12
# 3  2018  2.177482e+12  2.583600e+12  4.070225e+11  1.442676e+12  6.610781e+12
# 2  2019  2.252447e+12  2.527553e+12  4.047967e+11  1.430410e+12  6.615206e+12
# 1  2020  2.254454e+12  2.476403e+12  3.742372e+11  1.140929e+12  6.246023e+12
# 0  2021  2.704241e+12  2.747771e+12  4.344432e+11  1.287509e+12  7.173965e+12
#
#    gmf_weight  fez_weight  afk_weight  ilf_weight
# 5    0.311052    0.394836    0.062969    0.231143
# 4    0.317469    0.382495    0.060287    0.239749
# 3    0.329383    0.390816    0.061570    0.218231
# 2    0.340495    0.382082    0.061192    0.216231
# 1    0.360942    0.396477    0.059916    0.182665
# 0    0.376952    0.383020    0.060558    0.179470

# %%
print(df1)
# Out:
#                  AFK       FEZ       GMF       ILF       val  \
# Date
# 2016-01-04  0.250000  0.250000  0.250000  0.250000  1.000000
# 2016-01-05  0.248583  0.247774  0.250947  0.251451  0.998756
# 2016-01-06  0.246315  0.243546  0.247299  0.246009  0.983168
# 2016-01-07  0.238520  0.240134  0.239195  0.236212  0.954060
# 2016-01-08  0.237387  0.237685  0.237511  0.233914  0.946496
# ...              ...       ...       ...       ...       ...
# 2022-12-23  0.293900  0.352705  0.385135  0.391451  1.423192
# 2022-12-27  0.296067  0.353522  0.393480  0.383140  1.426209
# 2022-12-28  0.291732  0.349256  0.387374  0.385467  1.413830
# 2022-12-29  0.294442  0.356336  0.394741  0.383805  1.429324
# 2022-12-30  0.290106  0.351253  0.390834  0.380480  1.412674
#
#             daily_returns_Asia  daily_returns_Africa  daily_returns_Europe  \
# Date
# 2016-01-04           -0.796028             -0.214900             -0.525847
# 2016-01-05            0.093972             -0.143689             -0.225578
# 2016-01-06           -0.357009             -0.214810             -0.411728
# 2016-01-07           -0.783405             -0.769421             -0.341124
# 2016-01-08           -0.169737             -0.107903             -0.243364
# ...                        ...                   ...                   ...
# 2022-12-23           -0.182298              0.347270              0.036465
# 2022-12-27            0.852498              0.218366              0.082151
# 2022-12-28           -0.601077             -0.427186             -0.413853
# 2022-12-29            0.750743              0.273475              0.715273
# 2022-12-30           -0.386884             -0.427150             -0.493711
#
#             daily_returns_Latam  daily_returns_Port  SP_500_daily_returns  \
# Date
# 2016-01-04            -0.616083           -2.152857                   NaN
# 2016-01-05             0.150470           -0.124825              0.201226
# 2016-01-06            -0.536569           -1.520115             -1.311542
# 2016-01-07            -0.941656           -2.835606             -2.370042
# 2016-01-08            -0.230457           -0.751461             -1.083841
# ...                         ...                 ...                   ...
# 2022-12-23             0.883867            1.085303              0.586806
# 2022-12-27            -0.813461            0.339553             -0.404960
# 2022-12-28             0.234123           -1.207993             -1.202063
# 2022-12-29            -0.165504            1.573986              1.746132
# 2022-12-30            -0.329563           -1.637309             -0.254073
#
#             Excess_Market_return   Ret_lag  Ret_lag_AFK  Ret_lag_ILF  \
# Date
# 2016-01-04                 -1.59       NaN          NaN          NaN
# 2016-01-05                  0.12 -2.152857    -0.214900    -0.616083
# 2016-01-06                 -1.35 -0.124825    -0.143689     0.150470
# 2016-01-07                 -2.44 -1.520115    -0.214810    -0.536569
# 2016-01-08                 -1.11 -2.835606    -0.769421    -0.941656
# ...                          ...       ...          ...          ...
# 2022-12-23                  0.51 -1.327985    -0.497133     0.000000
# 2022-12-27                 -0.51  1.085303     0.347270     0.883867
# 2022-12-28                 -1.23  0.339553     0.218366    -0.813461
# 2022-12-29                  1.87 -1.207993    -0.427186     0.234123
# 2022-12-30                 -0.22  1.573986     0.273475    -0.165504
#
#             Ret_lag_FEZ  Ret_lag_GMF
# Date
# 2016-01-04          NaN          NaN
# 2016-01-05    -0.525847    -0.796028
# 2016-01-06    -0.225578     0.093972
# 2016-01-07    -0.411728    -0.357009
# 2016-01-08    -0.341124    -0.783405
# ...                 ...          ...
# 2022-12-23    -0.396194    -0.434659
# 2022-12-27     0.036465    -0.182298
# 2022-12-28     0.082151     0.852498
# 2022-12-29    -0.413853    -0.601077
# 2022-12-30     0.715273     0.750743
#
# [1762 rows x 17 columns]

# %%
df1 = df1.reset_index()

print(df1['Date'])
# Out:
# 0      2016-01-04
# 1      2016-01-05
# 2      2016-01-06
# 3      2016-01-07
# 4      2016-01-08
#           ...
# 1757   2022-12-23
# 1758   2022-12-27
# 1759   2022-12-28
# 1760   2022-12-29
# 1761   2022-12-30
# Name: Date, Length: 1762, dtype: datetime64[ns]

# %%
df1['Year'] = df1['Date'].dt.year
df1[['Year']] = df1[['Year']].astype('int64')
df_flipped[['Year']] = df_flipped[['Year']].astype('int64')
df_flipped.dtypes
# Out:
# Year            int64
# GDPwg         float64
# GDPwf         float64
# GDPwa         float64
# GDPwi         float64
# Total         float64
# gmf_weight    float64
# fez_weight    float64
# afk_weight    float64
# ilf_weight    float64
# dtype: object

# %%
gdp_weighted = pd.merge(df_flipped, df1, on='Year')

print(gdp_weighted['Year'])
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2016
# 4       2016
#         ...
# 1506    2021
# 1507    2021
# 1508    2021
# 1509    2021
# 1510    2021
# Name: Year, Length: 1511, dtype: int64

# %%
gdp_weighted['Asia_weight'] = gdp_weighted['daily_returns_Asia']*gdp_weighted['gmf_weight']
gdp_weighted['Africa_weight'] = gdp_weighted['daily_returns_Africa']*gdp_weighted['afk_weight']
gdp_weighted['Europe_weight'] = gdp_weighted['daily_returns_Europe']*gdp_weighted['fez_weight']
gdp_weighted['Latam_weight'] = gdp_weighted['daily_returns_Latam']*gdp_weighted['ilf_weight']

df1 = df.dropna()
print(gdp_weighted[['Asia_weight', 'Africa_weight', 'Europe_weight', 'Latam_weight']])
# Out:
#       Asia_weight  Africa_weight  Europe_weight  Latam_weight
# 0       -0.247606      -0.013532      -0.207623     -0.142403
# 1        0.029230      -0.009048      -0.089066      0.034780
# 2       -0.111048      -0.013526      -0.162565     -0.124024
# 3       -0.243680      -0.048450      -0.134688     -0.217657
# 4       -0.052797      -0.006795      -0.096089     -0.053268
# ...           ...            ...            ...           ...
# 1506     0.078591       0.001095       0.147844      0.087752
# 1507    -0.096145      -0.024863      -0.017418     -0.026729
# 1508    -0.038278       0.008787      -0.010456     -0.085313
# 1509     0.248846       0.009893      -0.027852      0.130966
# 1510    -0.065740       0.006585       0.031450     -0.014883
#
# [1511 rows x 4 columns]

# %%
gdp_weighted['daily_gdp_returns'] = gdp_weighted['Asia_weight']+gdp_weighted['Africa_weight']+gdp_weighted['Europe_weight']+gdp_weighted['Latam_weight']

# %%
fig = plt.figure()
ax2 = fig.add_axes([0.1,0.1,1,1])
ax2.plot(gdp_weighted['daily_gdp_returns'])

ax2.set_xlabel("Date")
ax2.set_ylabel("Percent")
ax2.set_title("GDP Weighted Daily Returns")

plt.show()

# %%
1500**(1/3)
# Out:
# 11.447142425533317

# %%
gdp_weighted['GDPRet_lag'] = gdp_weighted['daily_gdp_returns'].shift()
# this is my regression model
reg = smf.ols("Excess_Market_return~GDPRet_lag", data=gdp_weighted).fit(cov_type='HAC',
                                                                        cov_kwds={"maxlags":11})
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Excess_Market_return   R-squared:                       0.022
# Model:                              OLS   Adj. R-squared:                  0.022
# Method:                   Least Squares   F-statistic:                     3.046
# Date:                  Sat, 08 Apr 2023   Prob (F-statistic):             0.0811
# Time:                          15:28:52   Log-Likelihood:                -2370.7
# No. Observations:                  1510   AIC:                             4745.
# Df Residuals:                      1508   BIC:                             4756.
# Df Model:                             1
# Covariance Type:                    HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0765      0.029      2.624      0.009       0.019       0.134
# GDPRet_lag    -0.4273      0.245     -1.745      0.081      -0.907       0.053
# ==============================================================================
# Omnibus:                      544.824   Durbin-Watson:                   2.155
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19626.239
# Skew:                          -1.000   Prob(JB):                         0.00
# Kurtosis:                      20.548   Cond. No.                         2.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 11 lags and without small sample correction
# """

# %%
gdp_weighted['GDPRet_lag_1'] = gdp_weighted['daily_gdp_returns'].shift()
gdp_weighted['GDPRet_lag_2'] = gdp_weighted['daily_gdp_returns'].shift(2)
gdp_weighted['GDPRet_lag_4'] = gdp_weighted['daily_gdp_returns'].shift(4)
gdp_weighted['GDPRet_lag_8'] = gdp_weighted['daily_gdp_returns'].shift(8)
gdp_weighted['GDPRet_lag_16'] = gdp_weighted['daily_gdp_returns'].shift(16)
gdp_weighted['GDPRet_lag_32'] = gdp_weighted['daily_gdp_returns'].shift(32)
# this is my regression model
# define the independent variables
x = gdp_weighted[['GDPRet_lag_1','GDPRet_lag_2','GDPRet_lag_4','GDPRet_lag_8','GDPRet_lag_16','GDPRet_lag_32']]

reg = smf.ols("Excess_Market_return~x", data=gdp_weighted).fit(cov_type='HAC',
                                                              cov_kwds={"maxlags":11})
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Excess_Market_return   R-squared:                       0.054
# Model:                              OLS   Adj. R-squared:                  0.050
# Method:                   Least Squares   F-statistic:                     2.061
# Date:                  Sat, 08 Apr 2023   Prob (F-statistic):             0.0549
# Time:                          15:54:57   Log-Likelihood:                -2289.1
# No. Observations:                  1479   AIC:                             4592.
# Df Residuals:                      1472   BIC:                             4629.
# Df Model:                             6
# Covariance Type:                    HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0812      0.029      2.760      0.006       0.024       0.139
# x[0]          -0.3702      0.197     -1.880      0.060      -0.756       0.016
# x[1]           0.3010      0.185      1.629      0.103      -0.061       0.663
# x[2]          -0.1363      0.129     -1.056      0.291      -0.389       0.117
# x[3]          -0.3224      0.166     -1.937      0.053      -0.648       0.004
# x[4]           0.1467      0.068      2.145      0.032       0.013       0.281
# x[5]          -0.0169      0.087     -0.194      0.846      -0.187       0.154
# ==============================================================================
# Omnibus:                      530.107   Durbin-Watson:                   2.145
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15143.832
# Skew:                          -1.057   Prob(JB):                         0.00
# Kurtosis:                      18.533   Cond. No.                         2.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 11 lags and without small sample correction
# """

# %%
gdp_weighted['GDPRet_lag_gmf_1'] = gdp_weighted['Asia_weight'].shift()
gdp_weighted['GDPRet_lag_gmf_2'] = gdp_weighted['Asia_weight'].shift(2)
gdp_weighted['GDPRet_lag_gmf_4'] = gdp_weighted['Asia_weight'].shift(4)
gdp_weighted['GDPRet_lag_gmf_8'] = gdp_weighted['Asia_weight'].shift(8)
gdp_weighted['GDPRet_lag_gmf_16'] = gdp_weighted['Asia_weight'].shift(16)
gdp_weighted['GDPRet_lag_gmf_32'] = gdp_weighted['Asia_weight'].shift(32)
# this is my regression model
# define independent variables
x = gdp_weighted[['GDPRet_lag_gmf_1','GDPRet_lag_gmf_2','GDPRet_lag_gmf_4','GDPRet_lag_gmf_8','GDPRet_lag_gmf_16','GDPRet_lag_gmf_32']]
reg = smf.ols("Excess_Market_return~x", data=gdp_weighted).fit(cov_type='HAC',
                                                                        cov_kwds={"maxlags":11})
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Excess_Market_return   R-squared:                       0.051
# Model:                              OLS   Adj. R-squared:                  0.047
# Method:                   Least Squares   F-statistic:                     2.240
# Date:                  Sat, 08 Apr 2023   Prob (F-statistic):             0.0372
# Time:                          15:57:26   Log-Likelihood:                -2291.3
# No. Observations:                  1479   AIC:                             4597.
# Df Residuals:                      1472   BIC:                             4634.
# Df Model:                             6
# Covariance Type:                    HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0799      0.029      2.803      0.005       0.024       0.136
# x[0]          -0.9796      0.540     -1.814      0.070      -2.038       0.079
# x[1]           0.7419      0.463      1.601      0.109      -0.166       1.650
# x[2]          -0.2364      0.294     -0.805      0.421      -0.812       0.340
# x[3]          -0.7586      0.417     -1.821      0.069      -1.575       0.058
# x[4]           0.3942      0.174      2.266      0.023       0.053       0.735
# x[5]          -0.0242      0.190     -0.127      0.899      -0.396       0.348
# ==============================================================================
# Omnibus:                      519.366   Durbin-Watson:                   2.179
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15310.693
# Skew:                          -1.013   Prob(JB):                         0.00
# Kurtosis:                      18.632   Cond. No.                         6.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 11 lags and without small sample correction
# """

# %%
gdp_weighted['GDPRet_lag_afk'] = gdp_weighted['Africa_weight'].shift()
# this is my regression model
reg = smf.ols("Excess_Market_return~GDPRet_lag_afk", data=gdp_weighted).fit(cov_type='HAC',
                                                                        cov_kwds={"maxlags":11})
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Excess_Market_return   R-squared:                       0.006
# Model:                              OLS   Adj. R-squared:                  0.005
# Method:                   Least Squares   F-statistic:                     2.158
# Date:                  Sat, 08 Apr 2023   Prob (F-statistic):              0.142
# Time:                          15:37:18   Log-Likelihood:                -2383.4
# No. Observations:                  1510   AIC:                             4771.
# Df Residuals:                      1508   BIC:                             4781.
# Df Model:                             1
# Covariance Type:                    HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.0714      0.028      2.561      0.010       0.017       0.126
# GDPRet_lag_afk    -3.6706      2.499     -1.469      0.142      -8.568       1.227
# ==============================================================================
# Omnibus:                      542.003   Durbin-Watson:                   2.332
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23553.339
# Skew:                          -0.935   Prob(JB):                         0.00
# Kurtosis:                      22.258   Cond. No.                         41.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 11 lags and without small sample correction
# """

# %%
gdp_weighted['GDPRet_lag_fez'] = gdp_weighted['Europe_weight'].shift()
# this is my regression model
reg = smf.ols("Excess_Market_return~GDPRet_lag_fez", data=gdp_weighted).fit(cov_type='HAC',
                                                                        cov_kwds={"maxlags":11})
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Excess_Market_return   R-squared:                       0.016
# Model:                              OLS   Adj. R-squared:                  0.015
# Method:                   Least Squares   F-statistic:                     2.504
# Date:                  Sat, 08 Apr 2023   Prob (F-statistic):              0.114
# Time:                          15:37:34   Log-Likelihood:                -2376.0
# No. Observations:                  1510   AIC:                             4756.
# Df Residuals:                      1508   BIC:                             4767.
# Df Model:                             1
# Covariance Type:                    HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.0745      0.029      2.588      0.010       0.018       0.131
# GDPRet_lag_fez    -0.9961      0.630     -1.582      0.114      -2.230       0.238
# ==============================================================================
# Omnibus:                      542.606   Durbin-Watson:                   2.195
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21007.948
# Skew:                          -0.972   Prob(JB):                         0.00
# Kurtosis:                      21.169   Cond. No.                         6.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 11 lags and without small sample correction
# """

# %%
gdp_weighted['GDPRet_lag_ilf'] = gdp_weighted['Latam_weight'].shift()
# this is my regression model
reg = smf.ols("Excess_Market_return~GDPRet_lag_ilf", data=gdp_weighted).fit(cov_type='HAC',
                                                                        cov_kwds={"maxlags":11})
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Excess_Market_return   R-squared:                       0.015
# Model:                              OLS   Adj. R-squared:                  0.014
# Method:                   Least Squares   F-statistic:                     2.496
# Date:                  Sat, 08 Apr 2023   Prob (F-statistic):              0.114
# Time:                          15:37:41   Log-Likelihood:                -2376.6
# No. Observations:                  1510   AIC:                             4757.
# Df Residuals:                      1508   BIC:                             4768.
# Df Model:                             1
# Covariance Type:                    HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.0734      0.028      2.612      0.009       0.018       0.128
# GDPRet_lag_ilf    -1.0044      0.636     -1.580      0.114      -2.250       0.242
# ==============================================================================
# Omnibus:                      527.239   Durbin-Watson:                   2.274
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20034.323
# Skew:                          -0.929   Prob(JB):                         0.00
# Kurtosis:                      20.748   Cond. No.                         7.04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 11 lags and without small sample correction
# """

# %%
#testing for highest r
gdp_weighted['highest_r'] = gdp_weighted['Asia_weight']+gdp_weighted['Europe_weight']+gdp_weighted['Latam_weight']+gdp_weighted['Africa_weight']

gdp_weighted['GDPRet_lag_highest'] = gdp_weighted['highest_r'].shift()
# this is my regression model
reg = smf.ols("Excess_Market_return~GDPRet_lag_highest", data=gdp_weighted).fit(cov_type='HAC',
                                                                        cov_kwds={"maxlags":11})
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Excess_Market_return   R-squared:                       0.022
# Model:                              OLS   Adj. R-squared:                  0.022
# Method:                   Least Squares   F-statistic:                     3.046
# Date:                  Sat, 08 Apr 2023   Prob (F-statistic):             0.0811
# Time:                          15:37:50   Log-Likelihood:                -2370.7
# No. Observations:                  1510   AIC:                             4745.
# Df Residuals:                      1508   BIC:                             4756.
# Df Model:                             1
# Covariance Type:                    HAC
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.0765      0.029      2.624      0.009       0.019       0.134
# GDPRet_lag_highest    -0.4273      0.245     -1.745      0.081      -0.907       0.053
# ==============================================================================
# Omnibus:                      544.824   Durbin-Watson:                   2.155
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19626.239
# Skew:                          -1.000   Prob(JB):                         0.00
# Kurtosis:                      20.548   Cond. No.                         2.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 11 lags and without small sample correction
# """

# %% [markdown]
# ## Out of sample regression

# %%
gdp_weighted
# Out:
#       Year         GDPwg         GDPwf         GDPwa         GDPwi  \
# 0     2016  1.789134e+12  2.271046e+12  3.621915e+11  1.329505e+12
# 1     2016  1.789134e+12  2.271046e+12  3.621915e+11  1.329505e+12
# 2     2016  1.789134e+12  2.271046e+12  3.621915e+11  1.329505e+12
# 3     2016  1.789134e+12  2.271046e+12  3.621915e+11  1.329505e+12
# 4     2016  1.789134e+12  2.271046e+12  3.621915e+11  1.329505e+12
# ...    ...           ...           ...           ...           ...
# 1506  2021  2.704241e+12  2.747771e+12  4.344432e+11  1.287509e+12
# 1507  2021  2.704241e+12  2.747771e+12  4.344432e+11  1.287509e+12
# 1508  2021  2.704241e+12  2.747771e+12  4.344432e+11  1.287509e+12
# 1509  2021  2.704241e+12  2.747771e+12  4.344432e+11  1.287509e+12
# 1510  2021  2.704241e+12  2.747771e+12  4.344432e+11  1.287509e+12
#
#              Total  gmf_weight  fez_weight  afk_weight  ilf_weight  ...  \
# 0     5.751876e+12    0.311052    0.394836    0.062969    0.231143  ...
# 1     5.751876e+12    0.311052    0.394836    0.062969    0.231143  ...
# 2     5.751876e+12    0.311052    0.394836    0.062969    0.231143  ...
# 3     5.751876e+12    0.311052    0.394836    0.062969    0.231143  ...
# 4     5.751876e+12    0.311052    0.394836    0.062969    0.231143  ...
# ...            ...         ...         ...         ...         ...  ...
# 1506  7.173965e+12    0.376952    0.383020    0.060558    0.179470  ...
# 1507  7.173965e+12    0.376952    0.383020    0.060558    0.179470  ...
# 1508  7.173965e+12    0.376952    0.383020    0.060558    0.179470  ...
# 1509  7.173965e+12    0.376952    0.383020    0.060558    0.179470  ...
# 1510  7.173965e+12    0.376952    0.383020    0.060558    0.179470  ...
#
#      Europe_weight  Latam_weight  daily_gdp_returns  GDPRet_lag  \
# 0        -0.207623     -0.142403          -0.611164         NaN
# 1        -0.089066      0.034780          -0.034104   -0.611164
# 2        -0.162565     -0.124024          -0.411164   -0.034104
# 3        -0.134688     -0.217657          -0.644475   -0.411164
# 4        -0.096089     -0.053268          -0.208949   -0.644475
# ...            ...           ...                ...         ...
# 1506      0.147844      0.087752           0.315281    0.262273
# 1507     -0.017418     -0.026729          -0.165155    0.315281
# 1508     -0.010456     -0.085313          -0.125260   -0.165155
# 1509     -0.027852      0.130966           0.361853   -0.125260
# 1510      0.031450     -0.014883          -0.042588    0.361853
#
#       GDPRet_lag_gmf  GDPRet_lag_afk  GDPRet_lag_fez  GDPRet_lag_ilf  \
# 0                NaN             NaN             NaN             NaN
# 1          -0.247606       -0.013532       -0.207623       -0.142403
# 2           0.029230       -0.009048       -0.089066        0.034780
# 3          -0.111048       -0.013526       -0.162565       -0.124024
# 4          -0.243680       -0.048450       -0.134688       -0.217657
# ...              ...             ...             ...             ...
# 1506        0.115816        0.020993        0.119491        0.005973
# 1507        0.078591        0.001095        0.147844        0.087752
# 1508       -0.096145       -0.024863       -0.017418       -0.026729
# 1509       -0.038278        0.008787       -0.010456       -0.085313
# 1510        0.248846        0.009893       -0.027852        0.130966
#
#       highest_r  GDPRet_lag_highest
# 0     -0.611164                 NaN
# 1     -0.034104           -0.611164
# 2     -0.411164           -0.034104
# 3     -0.644475           -0.411164
# 4     -0.208949           -0.644475
# ...         ...                 ...
# 1506   0.315281            0.262273
# 1507  -0.165155            0.315281
# 1508  -0.125260           -0.165155
# 1509   0.361853           -0.125260
# 1510  -0.042588            0.361853
#
# [1511 rows x 40 columns]

# %%
dep_var = 'Excess_Market_return'
indep_var = 'GDPRet_lag'

gdp_weighted['OOS_Pred_Mean'] = gdp_weighted.expanding(min_periods=20)[dep_var].mean().shift()
gdp_weighted['OOS_Error_Mean'] = gdp_weighted[dep_var] - gdp_weighted['OOS_Pred_Mean']

# %%
def pred_from_OLS(x, dep_var, indep_var, window):
    """Compute the next period predicted value for univariate
    OLS regression.
    
    Note: 
        The x dataframe must contain dep_var, indep_var
        and the lagged indep_var.

    Args:
        x : The dataframe to use for computation
        dep_var : The dependant variable
        indep_var : The independant variable
        window : The minimum window length

    Returns:
        The predicted value or nan if data shorter than window.
    """
    if x[[dep_var, indep_var]].notnull().all(axis=1).sum() < window:
        return np.nan
    res = smf.ols(dep_var + '~' + indep_var, data=x).fit()
    indep_var_t = x[indep_var].iloc[-1]
    return res.params['Intercept'] + res.params[indep_var] * indep_var_t  # this gives you the expected market returns using your predictor
gdp_weighted['OOS_Pred_OLS_1'] = np.nan
for i in range(len(gdp_weighted)):
    gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
                                                 indep_var, window=20)
gdp_weighted['OOS_Pred_OLS'] = gdp_weighted['OOS_Pred_OLS_1'].shift()
del gdp_weighted['OOS_Pred_OLS_1']  # delete that columns

gdp_weighted['OOS_Error_OLS'] = gdp_weighted[dep_var] - gdp_weighted['OOS_Pred_OLS']
# Out:
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,
# C:\Users\wang1427\AppData\Local\Temp\ipykernel_11140\2775328510.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_weighted['OOS_Pred_OLS_1'].iloc[i] = pred_from_OLS(gdp_weighted.iloc[0:i+1], dep_var,

# %%
1-((gdp_weighted['OOS_Error_OLS'] ** 2).sum()/(gdp_weighted['OOS_Error_Mean'] ** 2).sum())
# to have a good predictor, you must have a positive OOS R2.
# Out:
# -0.05135334070313413

# %%
gdp_weighted
# Out:
#       Year         GDPwg         GDPwf         GDPwa         GDPwi  \
# 0     2016  1.789134e+12  2.271046e+12  3.621915e+11  1.329505e+12
# 1     2016  1.789134e+12  2.271046e+12  3.621915e+11  1.329505e+12
# 2     2016  1.789134e+12  2.271046e+12  3.621915e+11  1.329505e+12
# 3     2016  1.789134e+12  2.271046e+12  3.621915e+11  1.329505e+12
# 4     2016  1.789134e+12  2.271046e+12  3.621915e+11  1.329505e+12
# ...    ...           ...           ...           ...           ...
# 1506  2021  2.704241e+12  2.747771e+12  4.344432e+11  1.287509e+12
# 1507  2021  2.704241e+12  2.747771e+12  4.344432e+11  1.287509e+12
# 1508  2021  2.704241e+12  2.747771e+12  4.344432e+11  1.287509e+12
# 1509  2021  2.704241e+12  2.747771e+12  4.344432e+11  1.287509e+12
# 1510  2021  2.704241e+12  2.747771e+12  4.344432e+11  1.287509e+12
#
#              Total  gmf_weight  fez_weight  afk_weight  ilf_weight  ...  \
# 0     5.751876e+12    0.311052    0.394836    0.062969    0.231143  ...
# 1     5.751876e+12    0.311052    0.394836    0.062969    0.231143  ...
# 2     5.751876e+12    0.311052    0.394836    0.062969    0.231143  ...
# 3     5.751876e+12    0.311052    0.394836    0.062969    0.231143  ...
# 4     5.751876e+12    0.311052    0.394836    0.062969    0.231143  ...
# ...            ...         ...         ...         ...         ...  ...
# 1506  7.173965e+12    0.376952    0.383020    0.060558    0.179470  ...
# 1507  7.173965e+12    0.376952    0.383020    0.060558    0.179470  ...
# 1508  7.173965e+12    0.376952    0.383020    0.060558    0.179470  ...
# 1509  7.173965e+12    0.376952    0.383020    0.060558    0.179470  ...
# 1510  7.173965e+12    0.376952    0.383020    0.060558    0.179470  ...
#
#      GDPRet_lag_gmf  GDPRet_lag_afk  GDPRet_lag_fez  GDPRet_lag_ilf  \
# 0               NaN             NaN             NaN             NaN
# 1         -0.247606       -0.013532       -0.207623       -0.142403
# 2          0.029230       -0.009048       -0.089066        0.034780
# 3         -0.111048       -0.013526       -0.162565       -0.124024
# 4         -0.243680       -0.048450       -0.134688       -0.217657
# ...             ...             ...             ...             ...
# 1506       0.115816        0.020993        0.119491        0.005973
# 1507       0.078591        0.001095        0.147844        0.087752
# 1508      -0.096145       -0.024863       -0.017418       -0.026729
# 1509      -0.038278        0.008787       -0.010456       -0.085313
# 1510       0.248846        0.009893       -0.027852        0.130966
#
#       highest_r  GDPRet_lag_highest  OOS_Pred_Mean  OOS_Error_Mean  \
# 0     -0.611164                 NaN            NaN             NaN
# 1     -0.034104           -0.611164            NaN             NaN
# 2     -0.411164           -0.034104            NaN             NaN
# 3     -0.644475           -0.411164            NaN             NaN
# 4     -0.208949           -0.644475            NaN             NaN
# ...         ...                 ...            ...             ...
# 1506   0.315281            0.262273       0.067490        1.152510
# 1507  -0.165155            0.315281       0.068255       -0.338255
# 1508  -0.125260           -0.165155       0.068031       -0.008031
# 1509   0.361853           -0.125260       0.068025       -0.218025
# 1510  -0.042588            0.361853       0.067881       -0.377881
#
#       OOS_Pred_OLS  OOS_Error_OLS
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# ...            ...            ...
# 1506     -0.111518       1.331518
# 1507     -0.034961      -0.235039
# 1508     -0.057808       0.117808
# 1509      0.147375      -0.297375
# 1510      0.130126      -0.440126
#
# [1511 rows x 44 columns]
